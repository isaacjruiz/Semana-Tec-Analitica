# %%
import seaborn, matplotlib
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math

# Cargando datos
data = pd.read_csv("covid19_tweets.csv")

# Cantidad de datos que se tienen
datosVariable = data.count()
datosTotales = sum(data.count())

print("\n ---> Cantidad de datos por variable")
print(datosVariable)
print("\n ---> Cantidad de datos que se tienen = ",datosTotales)

# Variables que contiene cada vector
def variablesVector(matriz):
    variables = data.columns.values
    for i in range(0, len(variables)):
        print(variables[i])

print(" \n ---> Variables que contiene cada vector")
variablesVector(data)

# Tipo de variables
tiposVariables = data.dtypes

print("\n --->Tipos de variables")
print(tiposVariables)

# Rangos en los que se encuentran las variables
print(data.max())
print(data.min())
print("\n ---> Rango de user_followers = de ",data["user_followers"].min(skipna=0), "hasta",data["user_followers"].max())
print("---> Rango de user_friends = de ",data["user_friends"].min(), "hasta",data["user_friends"].max())
print("---> Rango de user_favourites = de ",data["user_favourites"].min(), "hasta",data["user_favourites"].max())

#Diagrama de correlación

new_data = data[['user_followers','user_friends','user_favourites']]
sns.pairplot(new_data)
plt.show()


# Obtención de media, mediana y desviación estándar
estadistica = data.describe()
print("\n --->Media, Mediana y Desviación estándar")
print(estadistica)
# Out:
#  ---> Cantidad de datos por variable
# user_name           74436
# user_location       59218
# user_description    70079
# user_created        74436
# user_followers      74436
# user_friends        74436
# user_favourites     74436
# user_verified       74436
# date                74436
# text                74436
# hashtags            53002
# source              74424
# is_retweet          74436
# dtype: int64
#
#  ---> Cantidad de datos que se tienen =  926647
#
#  ---> Variables que contiene cada vector
# user_name
# user_location
# user_description
# user_created
# user_followers
# user_friends
# user_favourites
# user_verified
# date
# text
# hashtags
# source
# is_retweet
#
#  --->Tipos de variables
# user_name           object
# user_location       object
# user_description    object
# user_created        object
# user_followers       int64
# user_friends         int64
# user_favourites      int64
# user_verified         bool
# date                object
# text                object
# hashtags            object
# source              object
# is_retweet            bool
# dtype: object
# user_name                                                   🪐𝚂𝚝𝚘𝚍𝚒𝚞𝚜
# user_created                                     2020-08-04 07:29:18
# user_followers                                              13892841
# user_friends                                                  497363
# user_favourites                                              2047197
# user_verified                                                   True
# date                                             2020-08-04 07:57:03
# text               🧼 More ceramic soap dishes and dispensers by a...
# is_retweet                                                     False
# dtype: object
# user_name                                                     Corona
# user_created                                     1970-01-01 00:00:00
# user_followers                                                     0
# user_friends                                                       0
# user_favourites                                                    0
# user_verified                                                  False
# date                                             2020-07-24 23:47:08
# text               !!! #TWEETofTheDay AND #SCIENCEofTheDay :  #Co...
# is_retweet                                                     False
# dtype: object
# C:\Users\isaac\AppData\Local\Temp\ipykernel_18820\1325013382.py:34: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   print(data.max())
# C:\Users\isaac\AppData\Local\Temp\ipykernel_18820\1325013382.py:35: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   print(data.min())
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [5], in <cell line: 36>()
#      34 print(data.max())
#      35 print(data.min())
# ---> 36 print("\n ---> Rango de user_followers = de ",data["user_followers"].min(skipna=0), "hasta",data["user_followers"].max())
#      37 print("---> Rango de user_friends = de ",data["user_friends"].min(), "hasta",data["user_friends"].max())
#      38 print("---> Rango de user_favourites = de ",data["user_favourites"].min(), "hasta",data["user_favourites"].max())
#
# File ~\anaconda3\envs\SemanaTec\lib\site-packages\pandas\core\generic.py:11237, in NDFrame._add_numeric_operations.<locals>.min(self, axis, skipna, level, numeric_only, **kwargs)
#   11217 @doc(  # type: ignore[misc]
#   11218     _num_doc,
#   11219     desc="Return the minimum of the values over the requested axis.\n\n"
#    (...)
#   11235     **kwargs,
#   11236 ):
# > 11237     return NDFrame.min(self, axis, skipna, level, numeric_only, **kwargs)
#
# File ~\anaconda3\envs\SemanaTec\lib\site-packages\pandas\core\generic.py:10651, in NDFrame.min(self, axis, skipna, level, numeric_only, **kwargs)
#   10643 def min(
#   10644     self,
#   10645     axis: Axis | None | lib.NoDefault = lib.no_default,
#    (...)
#   10649     **kwargs,
#   10650 ):
# > 10651     return self._stat_function(
#   10652         "min",
#   10653         nanops.nanmin,
#   10654         axis,
#   10655         skipna,
#   10656         level,
#   10657         numeric_only,
#   10658         **kwargs,
#   10659     )
#
# File ~\anaconda3\envs\SemanaTec\lib\site-packages\pandas\core\generic.py:10610, in NDFrame._stat_function(self, name, func, axis, skipna, level, numeric_only, **kwargs)
#   10607 else:
#   10608     nv.validate_stat_func((), kwargs, fname=name)
# > 10610 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
#   10612 if axis is None and level is None and self.ndim > 1:
#   10613     # user must have explicitly passed axis=None
#   10614     # GH#21597
#   10615     warnings.warn(
#   10616         f"In a future version, DataFrame.{name}(axis=None) will return a "
#   10617         f"scalar {name} over the entire DataFrame. To retain the old "
#    (...)
#   10620         stacklevel=find_stack_level(),
#   10621     )
#
# File ~\anaconda3\envs\SemanaTec\lib\site-packages\pandas\util\_validators.py:251, in validate_bool_kwarg(value, arg_name, none_allowed, int_allowed)
#     248     good_value = good_value or isinstance(value, int)
#     250 if not good_value:
# --> 251     raise ValueError(
#     252         f'For argument "{arg_name}" expected type bool, received '
#     253         f"type {type(value).__name__}."
#     254     )
#     255 return value
#
# ValueError: For argument "skipna" expected type bool, received type int.
